# %% [markdown]
# ## Ejercicios - matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib # Para ver la versión
import matplotlib.pyplot as plt

# %%
# Versiones

print(f"numpy=={np.__version__}")
print(f"pandas=={pd.__version__}")
print(f"matplotlib=={matplotlib.__version__}")
# Out:
# numpy==2.2.1
# pandas==2.2.3
# matplotlib==3.10.0

# %% [markdown]
# ### Ejercicio 1:
# - Gráfica una recta de $(-7, -7)$ a $(7, 7)$ de color rosa.

# %% [markdown]
# ### Ejercicio 2:
# - Obtén el siguiente resultado utilizando subplot y la recta anterior.
#
# <div align="center">
#    <img src="attachment:b786bba5-1800-493f-93f4-8e1a34f4b76a.jpg" width="600">
# </div>

# %% [markdown]
# ### Ejercicio 3:
# - Obtén la siguiente gráfica de barras.
#
# <div align="center">
#    <img src="attachment:1f9b421d-9902-4e70-a5ec-c4cfd09920cd.jpg" width="600">
# </div>

# %% [markdown]
# ### Ejercicio 4:
# - Obtener el histograma de la columna _**Ancho Petalo**_ dataset de la **iris**.
#
# <div align="center">
#    <img src="attachment:86f9fa94-2d2e-44ce-a8ee-1ae258d0a364.jpg" width="600">
# </div>

# %%
df = pd.read_csv('../Data/iris.csv')
df.head()
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3           4.6           3.1           1.5           0.2  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa

# %%
# histograma con matplotlib
plt.hist(df['Ancho Petalo'], bins=10, color='magenta')
plt.show()

# %%
# histograma desde pandas, usa matplotlib
plt.figure(figsize=(4,3))
df['Ancho Petalo'].hist(bins=10, color='magenta')
plt.grid(visible=False)
plt.show()

# %% [markdown]
# ### Ejercicio 5:
# - Obtener un histograma con las columnas _**Largo Petalo**_ y _**Ancho Petalo**_ del dataset de **iris**.
#
# <div align="center">
#    <img src="attachment:8504ba8d-93c1-4056-b6c0-362f0d0fcfd1.jpg" width="600">
# </div>

# %%
# Por separado:
plt.figure(figsize=(3,3))
plt.hist(df['Largo Petalo'], alpha = 0.5)
plt.show()

plt.figure(figsize=(3,3))
plt.hist(df['Ancho Petalo'], alpha = 0.5)
plt.show()

# %%
# superpuestos: ideal si están relacionados o se quieren comparar, y tienen escalas cercanas
plt.hist(df['Largo Petalo'], alpha = 0.5)
plt.hist(df['Ancho Petalo'], alpha = 0.5)
plt.show()

# %%
# en horizontal
plt.hist(df['Largo Petalo'], alpha = 0.5, orientation='horizontal')
plt.hist(df['Ancho Petalo'], alpha = 0.5, orientation='horizontal')
plt.show()

# %%
plt.figure(figsize = (8, 4))

# una fila y dos columnas
plt.subplot(1, 2, 1)
plt.hist(df['Largo Petalo'], alpha = 0.5)

plt.subplot(1, 2, 2)
plt.hist(df['Ancho Petalo'], alpha = 0.5)

plt.show()

# %%
plt.figure(figsize = (4, 4))

# dos filas y una columna
plt.subplot(2, 1, 1)
plt.hist(df['Largo Petalo'], alpha = 0.5)

plt.subplot(2, 1, 2)
plt.hist(df['Ancho Petalo'], alpha = 0.5)

plt.show()

# %%
# opción para generar los histogramas de todas las columnas numéricas de golpe:
df.hist(grid=False, bins=20);

# %% [markdown]
# ### Ejercicio 6:
# - Guarda el dataset de titanic en una variable.

# %%
df = pd.read_csv('../Data/titanic.csv')
df.head(2)
# Out:
#    PassengerId                                               Name     Sex  \
# 0            1                            Braund, Mr. Owen Harris    male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
#
#     Age  Survived  Pclass     Ticket     Fare
# 0  22.0         0       3  A/5 21171   7.2500
# 1  38.0         1       1   PC 17599  71.2833

# %% [markdown]
# ### Ejercicio 7:
# - Muestra en una grafica de barras el número de hombres y mujeres que sobrevivieron.
#
# <div align="center">
#    <img src="attachment:559ebd1d-462e-45f4-865e-c96683726f34.jpg" width="500">
# </div>

# %%
# filtro sobrerivieron sí
df[df['Survived'] == 1]
# Out:
#      PassengerId                                               Name     Sex  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 8              9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9             10                Nasser, Mrs. Nicholas (Adele Achem)  female
# ..           ...                                                ...     ...
# 875          876                   Najib, Miss. Adele Kiamie "Jane"  female
# 879          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 880          881       Shelley, Mrs. William (Imanita Parrish Hall)  female
# 887          888                       Graham, Miss. Margaret Edith  female
# 889          890                              Behr, Mr. Karl Howell    male
#
#       Age  Survived  Pclass            Ticket     Fare
# ...

# %%
# df[df['Survived'] == 1]['Sex'].value_counts()
df[df['Survived'] == 1].value_counts('Sex')
# Out:
# Sex
# female    233
# male      109
# Name: count, dtype: int64

# %%
# value_counts nos da los conteos que podemos usar para las gráficas de barras
etiquetas = df[df['Survived'] == 1].value_counts('Sex').index
valores = df[df['Survived'] == 1].value_counts('Sex').values
plt.bar(etiquetas, valores);

# %%
# countplot se seaborn simplifica el conteo y visualización con un solo método
import seaborn as sns
sns.countplot(df, x='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(df[df['Survived'] == 1], x='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# ### Ejercicio 8:
# - Muestra en una gráfica el número de sobrevivientes por clase (_**Pclass**_).
#
# <div align="center">
#    <img src="attachment:8c1610fb-e51d-4a64-b99d-0e21689142ca.jpg" width="500">
# </div>

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# etiquetas = df[df['Survived'] == 1].value_counts('Pclass').index
etiquetas = [f"clase {i}" for i in df[df['Survived'] == 1].value_counts('Pclass', sort=False).index]
valores = df[df['Survived'] == 1].value_counts('Pclass', sort=False).values
plt.bar(etiquetas, valores, color = ['blue', 'green', 'red']);

# %%
df[df['Survived'] == 1].value_counts('Pclass', sort=False).plot(kind='bar', color=['blue', 'green', 'red'])
# Out:
# <Axes: xlabel='Pclass'>

# %%
sns.countplot(df[df['Survived'] == 1], x='Pclass', hue='Pclass', palette='viridis')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# ### Ejercicio 9:
# - Muestra en una gráfica de sectores el número de los que no sobrevivieron por clase (_**Pclass**_).
#
# <div align="center">
#    <img src="attachment:50341813-9c49-43ba-bd88-e7f0e26d1e2b.jpg" width="500">
# </div>

# %%
# df[df['Survived'] == 0].value_counts('Pclass', sort=False)
df[df['Survived'] == 0].value_counts('Pclass', sort=False, normalize=True)
# Out:
# Pclass
# 1    0.145719
# 2    0.176685
# 3    0.677596
# Name: proportion, dtype: float64

# %%
# normalize True nos da las proporciones en vez de los conteos
values = df[df['Survived'] == 0].value_counts('Pclass', sort=False, normalize=True)
# labels= ['Clase 1', 'Clase 2', 'Clase 3']
labels = sorted([f"clase {i}" for i in df['Pclass'].unique()])

plt.pie(x=values, 
        labels=labels, 
        shadow=True, 
        colors=['green', 'red', 'cyan'], 
        explode = (0.1, 0.1, 0.1),
        autopct = "%1.2f%%",
        textprops={'fontsize': 15},
        labeldistance=1.45
        );

# %% [markdown]
# ### Ejercicio 10:
# - Muestra en 2 graficas de sectores con _**plt.subplots()**_ la siguiente información:
#     1. En la primera gráfica mostrar el número de pasajeros que murieron de cada clase.
#     2. En la segunda gráfica mostrar el número de pasajeros que sobrevivieron de cada clase.
#
# <div align="center">
#    <img src="attachment:2e513e59-488b-470f-9217-83ac3636195a.jpg" width="600">
# </div>

# %%
labels = sorted([f"clase {i}" for i in df['Pclass'].unique()])

plt.subplot(1, 2, 1)
values = df[df['Survived'] == 0].value_counts('Pclass', sort=False, normalize=True)
plt.pie(x=values, 
        labels=labels, 
        colors=['green', 'red', 'cyan'], 
        explode = (0.1, 0.1, 0.1),
        autopct = "%1.2f%%")

plt.subplot(1, 2, 2)
values = df[df['Survived'] == 1].value_counts('Pclass', sort=False, normalize=True)
plt.pie(x=values, 
        labels=labels, 
        colors=['green', 'red', 'cyan'], 
        explode = (0.1, 0.1, 0.1),
        autopct = "%1.2f%%")

plt.title("Not survived vs. Survived %");

# %% [markdown]
# ### Ejercicio 11:
# - Muestra en una gráfica lineal las edades de los pasajeros que sobrevivieron y en otra la de los pasajeros que no sobrevivieron.
#
# <div align="center">
#    <img src="attachment:115dd486-1602-47dc-bfc6-0076ea0111a6.jpg">
# </div>

# %%
plt.figure(figsize=(20, 3))
plt.plot(df[df['Survived'] == 1]['Age'], color="green")
plt.plot(df[df['Survived'] == 0]['Age'], color="red");

# %% [markdown]
# ### Ejercicio 12:
# - Muestra en una grafica de caja la edad de los que sobrevivieron y de los que no sobrevivieron.
#
# **Nota**: Para poder graficarlo hay que reemplazar los NaN por el promedio de edad.
#
# <div align="center">
#    <img src="attachment:514ea044-a974-4b65-8a0f-0ed25f08bd5c.jpg">
# </div>

# %%
# fillna de la columna Age para rellenar nulos
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
# mismo boxplot
etiquetas = ['Not survived', 'Survived']
data = [
    df[df['Survived'] == 0]['Age'], 
    df[df['Survived'] == 1]['Age']
]
plt.boxplot(x = data, tick_labels=etiquetas, showmeans=True);
# plt.grid()

# %%
# dos gráficos boxplot diferentes:
plt.boxplot(x = df[df['Survived'] == 0]['Age'], tick_labels=['Not survived']);
plt.show()
plt.boxplot(x = df[df['Survived'] == 1]['Age'], tick_labels=['Survived']);
plt.show()

# %% [markdown]
# ### Ejercicio 13:
# - Mostrar en una gráfica de caja por clase la edad de los pasajeros.
#
# <div align="center">
#    <img src="attachment:b903f198-5353-4bc2-adcf-750bc3611372.jpg" width="600">
# </div>

# %%
etiquetas = ['Clase 1', 'Clase 2', 'Clase 3']
data = [
    df[df['Pclass'] == 1]['Age'], 
    df[df['Pclass'] == 2]['Age'],
    df[df['Pclass'] == 3]['Age']
]
plt.boxplot(x = data, tick_labels=etiquetas, showmeans=True);

# %% [markdown]
# ### Ejercicio 14:
# - Muestra en una gráfica de dispersión (scatter) la edad de los pasajeros vs el costo de su ticket.
#
# <div align="center">
#    <img src="attachment:6c45ea5d-a73c-4143-b754-cd23952f7136.jpg" width="400">
# </div>

# %%
plt.scatter(x=df['Age'], y=df['Fare']);

# %%
# Filtrando por género
male = df['Sex'] == 'male'
female = df['Sex'] == 'female'

plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
plt.scatter(x=df[male]['Age'], y=df[male]['Fare'])

plt.subplot(1, 2, 2)
plt.scatter(x=df[female]['Age'], y=df[female]['Fare']);

# %% [markdown]
# ### Ejercicio 15:
# - Muestra en una gráfica de dispersión la clase vs el el precio del ticket.
#
# <div align="center">
#    <img src="attachment:df61987a-e171-4ca4-be89-077fa09ba3ee.jpg" width="400">
# </div>

# %%
# subplot Filtrando por Pclass: 1, 2, 3

class1 = df['Pclass'] == 1
class2 = df['Pclass'] == 2
class3 = df['Pclass'] == 3

plt.figure(figsize=(15, 6))
plt.subplot(1, 3, 1)
plt.scatter(x=df[class1]['Age'], y=df[class1]['Fare'])
plt.subplot(1, 3, 2)
plt.scatter(x=df[class2]['Age'], y=df[class2]['Fare']);
plt.subplot(1, 3, 3)
plt.scatter(x=df[class3]['Age'], y=df[class3]['Fare']);

# %%
# sns.scatterplot
#plt.figure(figsize=(15,15))
# sns.scatterplot(df, x='Age', y='Fare', hue='Survived', alpha=0.9, style='Sex')
sns.scatterplot(df, x='Age', y='Fare', hue='Survived', alpha=0.9)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(data=df, x='Pclass', y='Fare', hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x='Pclass', y='Fare', hue='Sex')
#plt.yticks([0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]);
# plt.yticks(range(0, 600, 25));
plt.yticks(range(0, 600, 20))
plt.xticks((1, 2, 3));
#plt.grid();

# %%
# personalizando etiquetas por tramos
plt.figure(figsize=(10, 10))
sns.scatterplot(data=df, x='Pclass', y='Fare', hue='Sex')
ticks_bajos = range(0, 110, 10)
ticks_medios = range(100, 330, 30)
ticks_altos = range(330, 530, 50)
ticks = np.concatenate([ticks_bajos, ticks_medios, ticks_altos])

plt.yticks(ticks)
plt.xticks((1, 2, 3));

# %%
# con zoom enfocado en un tramo por ejemplo de 0 a 95
plt.figure(figsize=(10, 10))
sns.scatterplot(data=df, x='Pclass', y='Fare', hue='Sex')
ticks_bajos = range(0, 110, 10)
ticks_medios = range(100, 330, 30)
ticks_altos = range(330, 530, 50)
ticks = np.concatenate([ticks_bajos, ticks_medios, ticks_altos])

plt.yticks(ticks)
plt.xticks((1, 2, 3))
plt.ylim(0, 95);

# %% [markdown]
# ### Ejercicio 16:
# - Muestra en un histograma la edad de los pasajeros que sobrevivieron y la edad de los que no.
#
# <div align="center">
#    <img src="attachment:577feafd-b4f8-4850-87e2-eda592e97a66.jpg" width="400">
# </div>

# %%
# plt.hist()

# %% [markdown]
# ### Ejercicio 17:
# - Muestra en un histograma el costo de boleto por clase.
#
# <div align="center">
#    <img src="attachment:70dadfaf-0106-4411-b2ee-d0d71bd65934.jpg" width="600">
# </div>

# %%
df['Pclass'].value_counts(normalize=True)
# Out:
# Pclass
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: proportion, dtype: float64

# %%
class1 = df['Pclass'] == 1
class2 = df['Pclass'] == 2
class3 = df['Pclass'] == 3

plt.figure(figsize=(16, 6))
plt.hist(x = df[class1]["Fare"], alpha=0.5, bins=80, color='Blue')
plt.hist(x = df[class2]["Fare"], alpha=0.5, bins=50, color='Red')
plt.hist(x = df[class3]["Fare"], alpha=0.5, bins=20, color='Green')
plt.xlim(0, 280) #zoom horizontal para ver mejor
# Out:
# (0.0, 280.0)

# %%
df.describe()
# Out:
#        PassengerId         Age    Survived      Pclass        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.361582    0.383838    2.308642   32.204208
# std     257.353842   13.019697    0.486592    0.836071   49.693429
# min       1.000000    0.420000    0.000000    1.000000    0.000000
# 25%     223.500000   22.000000    0.000000    2.000000    7.910400
# 50%     446.000000   28.000000    0.000000    3.000000   14.454200
# 75%     668.500000   35.000000    1.000000    3.000000   31.000000
# max     891.000000   80.000000    1.000000    3.000000  512.329200

# %%
df['Fare'].skew()
# Out:
# np.float64(4.787316519674893)

# %%
df['Fare'].kurtosis()
# Out:
# np.float64(33.39814088089868)

# %%
################################################################################################################################
